# %%
from random import *
list = []

# %%
for x in range(1,10):
    list.append(randint(1,20))

# %% [markdown]
# The ![c1.PNG](attachment:c1.PNG)

# %%
print(list)
# Out:
# [1, 2, 1, 1, 1, 1, 1, 2, 1, 11, 6, 7, 15, 11, 7, 6, 10, 13]
